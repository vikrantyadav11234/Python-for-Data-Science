# %% [markdown]
# # EDA

# %%
# Problem Statement
# Data
# Data Dictionary- Data about the data

# %% [markdown]
# # EDA
# - Exploratory Data Analysis

# %% [markdown]
# - Exploration of the data.
# - Looking at the data from different angles.
# - Try to get as many insights as we can from the data.

# %% [markdown]
# # Problem Statement

# %% [markdown]
# - XYZ is a  service providing company that provides customers with a one year subscription plan for their product.
# - The company wants to know if the customers will renew the subscription for the coming year or not.

# %% [markdown]
# # Data Dictionary

# %% [markdown]
# ## Dataset:
# - 1- Year
# - 2- Customer_id - unique id
# - 3- Phone_no
# - 4- Gender
# - 5- Age
# - 6- No of days subscribed - the number of days since the subscription
# - 7- Multi screen - does the customer have a single/ multiple screen subscription
# - 8- Mail subscription - customer receive mails or not
# - 9- Weekly mins watched - number of minutes watched weekly
# - 10- Minimum daily mins - minimum minutes watched
# - 11- Maximum daily mins - maximum minutes watched
# - 12- Weekly nights max mins - number of minutes watched at night time
# - 13- Videos watched - total number of videos watched
# - 14- Maximum_days_inactive - days since inactive
# - 15- Customer support calls - number of customer support calls
# - 16- Churn -
#     - 1- Yes
#     - 0 - No

# %% [markdown]
# # Impoorting the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading the dataset

# %%
data=pd.read_csv('data_regression.csv')

# %%
data.head()
# Out:
#    year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0  2015       100198  409-8743  Female   36                     62
# 1  2015       100643  340-5930  Female   39                    149
# 2  2015       100756  372-3750  Female   65                    126
# 3  2015       101595  331-4902  Female   24                    131
# 4  2015       101653  351-8398  Female   40                    191
#
#   multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 0           no              no               148.35                12.2
# 1           no              no               294.45                 7.7
# 2           no              no                87.30                11.9
# 3           no             yes               321.30                 9.5
# 4           no              no               243.00                10.9
#
#    maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 0               16.81                     82               1
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# - 1- Size of the data (Shape of the data)
# - 2- Columns in the data
# - 3- Information
# - 4- Statistical measures.
# - 5- Duplicate vlaues
# - 6- Null Values
# - 7- Outliers
# - 8- Univariate Analysis
# - 9- Bivariate Analysis

# %% [markdown]
# # Shape of the data

# %%
data.shape
# Out:
# (2000, 16)

# %% [markdown]
# - 2000 rows
# - 16 columns

# %% [markdown]
# # Column names

# %%
cols=data.columns
cols
# Out:
# Index(['year', 'customer_id', 'phone_no', 'gender', 'age',
#        'no_of_days_subscribed', 'multi_screen', 'mail_subscribed',
#        'weekly_mins_watched', 'minimum_daily_mins', 'maximum_daily_mins',
#        'weekly_max_night_mins', 'videos_watched', 'maximum_days_inactive',
#        'customer_support_calls', 'churn'],
#       dtype='object')

# %% [markdown]
# # Basic information about the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    2000 non-null   int64
#  1   customer_id             2000 non-null   int64
#  2   phone_no                2000 non-null   object
#  3   gender                  1976 non-null   object
#  4   age                     2000 non-null   int64
#  5   no_of_days_subscribed   2000 non-null   int64
#  6   multi_screen            2000 non-null   object
#  7   mail_subscribed         2000 non-null   object
#  8   weekly_mins_watched     2000 non-null   float64
#  9   minimum_daily_mins      2000 non-null   float64
#  10  maximum_daily_mins      2000 non-null   float64
#  11  weekly_max_night_mins   2000 non-null   int64
#  12  videos_watched          2000 non-null   int64
#  13  maximum_days_inactive   1972 non-null   float64
# ...

# %% [markdown]
# # Statistical measures

# %%
data.describe()
# Out:
#          year    customer_id         age  no_of_days_subscribed  \
# count  2000.0    2000.000000  2000.00000            2000.000000
# mean   2015.0  554887.157500    38.69050              99.750000
# std       0.0  261033.690318    10.20641              39.755386
# min    2015.0  100198.000000    18.00000               1.000000
# 25%    2015.0  328634.750000    32.00000              73.000000
# 50%    2015.0  567957.500000    37.00000              99.000000
# 75%    2015.0  773280.250000    44.00000             127.000000
# max    2015.0  999961.000000    82.00000             243.000000
#
#        weekly_mins_watched  minimum_daily_mins  maximum_daily_mins  \
# count          2000.000000         2000.000000         2000.000000
# mean            270.178425           10.198700           30.620780
# std              80.551627            2.785519            9.129165
# min               0.000000            0.000000            0.000000
# ...

# %% [markdown]
# # Duplicate values

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [year, customer_id, phone_no, gender, age, no_of_days_subscribed, multi_screen, mail_subscribed, weekly_mins_watched, minimum_daily_mins, maximum_daily_mins, weekly_max_night_mins, videos_watched, maximum_days_inactive, customer_support_calls, churn]
# Index: []

# %% [markdown]
# - There are no duplicate values

# %% [markdown]
# # Let's add some duplicate values to the dataset

# %%
new_data=data.iloc[101:121]
new_data
# Out:
#      year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 101  2015       138462  378-2940  Female   32                    148
# 102  2015       138764  395-4757    Male   28                     70
# 103  2015       138770  393-8736    Male   48                    149
# 104  2015       139612  405-5305  Female   24                     16
# 105  2015       139643  407-7258  Female   33                     54
# 106  2015       139974  333-4154    Male   46                     83
# 107  2015       141174  398-8385     NaN   39                     72
# 108  2015       141988  391-6607    Male   43                     30
# 109  2015       142130  406-3069    Male   36                     56
# 110  2015       143708  386-2923    Male   24                     93
# 111  2015       144052  422-9964    Male   48                     72
# 112  2015       144623  332-8103    Male   34                     91
# 113  2015       145394  383-1657    Male   37                    110
# ...

# %% [markdown]
# # Now concatenate new_data to data

# %%
data=pd.concat([new_data,data],axis=0,ignore_index=True)

# %%
# data=pd.concat([data,new_data],axis=0,ignore_index=True)

# %%
data.shape
# Out:
# (2020, 16)

# %%
data.head()
# Out:
#    year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 0  2015       138462  378-2940  Female   32                    148
# 1  2015       138764  395-4757    Male   28                     70
# 2  2015       138770  393-8736    Male   48                    149
# 3  2015       139612  405-5305  Female   24                     16
# 4  2015       139643  407-7258  Female   33                     54
#
#   multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 0           no             yes               379.35                12.3
# 1           no              no               189.45                 9.6
# 2           no              no               249.90                 8.2
# 3           no              no               344.40                10.8
# 4          yes              no               285.75                 9.7
#
#    maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 0               42.99                     99               1
# ...

# %%
data.iloc[20:30]
# Out:
#     year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 20  2015       100198  409-8743  Female   36                     62
# 21  2015       100643  340-5930  Female   39                    149
# 22  2015       100756  372-3750  Female   65                    126
# 23  2015       101595  331-4902  Female   24                    131
# 24  2015       101653  351-8398  Female   40                    191
# 25  2015       101953  329-6603     NaN   31                     65
# 26  2015       103051  416-1845     NaN   54                     59
# 27  2015       103225  348-7193  Female   40                     50
# 28  2015       103408  413-4039    Male   61                    205
# 29  2015       103676  338-5207    Male   31                     63
#
#    multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 20           no              no               148.35                12.2
# ...

# %%
data.iloc[101:103]
# Out:
#      year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 101  2015       129137  335-7257  Female   36                     92
# 102  2015       129487  377-9178  Female   39                    103
#
#     multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 101           no             yes                276.0                12.7
# 102           no              no                240.3                 9.7
#
#      maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# 101               31.28                     96               3
# 102               27.23                     97               2
#
#      maximum_days_inactive  customer_support_calls  churn
# 101                    NaN                       2    NaN
# 102                    NaN                       0    NaN

# %%
data.tail()
# Out:
#       year  customer_id  phone_no  gender  age  no_of_days_subscribed  \
# 2015  2015       997132  385-7387  Female   54                     75
# 2016  2015       998086  383-9255    Male   45                    127
# 2017  2015       998474  353-2080     NaN   53                     94
# 2018  2015       998934  359-7788    Male   40                     94
# 2019  2015       999961  414-1496    Male   37                     73
#
#      multi_screen mail_subscribed  weekly_mins_watched  minimum_daily_mins  \
# 2015           no             yes               182.25                11.3
# 2016           no              no               273.45                 9.3
# 2017           no              no               128.85                15.6
# 2018           no              no               178.05                10.4
# 2019           no              no               326.70                10.3
#
#       maximum_daily_mins  weekly_max_night_mins  videos_watched  \
# ...

# %% [markdown]
# # Let's check the duplicate values again

# %%
data.duplicated().sum()
# Out:
# 20

# %%
data[data.duplicated()].count()
# Out:
# year                      20
# customer_id               20
# phone_no                  20
# gender                    19
# age                       20
# no_of_days_subscribed     20
# multi_screen              20
# mail_subscribed           20
# weekly_mins_watched       20
# minimum_daily_mins        20
# maximum_daily_mins        20
# weekly_max_night_mins     20
# videos_watched            20
# maximum_days_inactive     19
# customer_support_calls    20
# churn                     19
# dtype: int64

# %%
# data=pd.concat([data_set_1,data_set_2],axis=1,ignore_index=True)

# %%
# 0-1999
# 0-9

# %%
# 0-1999
# 2000-2009

# %% [markdown]
# # Null Values

# %% [markdown]
# - Null values are the missing values and represented by nan

# %%
data.isna().sum()
# Out:
# year                       0
# customer_id                0
# phone_no                   0
# gender                    25
# age                        0
# no_of_days_subscribed      0
# multi_screen               0
# mail_subscribed            0
# weekly_mins_watched        0
# minimum_daily_mins         0
# maximum_daily_mins         0
# weekly_max_night_mins      0
# videos_watched             0
# maximum_days_inactive     29
# customer_support_calls     0
# churn                     36
# dtype: int64

# %% [markdown]
# - gender- 25 null values
# - maximum_days_inactive 29 values
# - churn 36 null values

# %%
data['year'].dtype
# Out:
# dtype('int64')

# %%
data.dtypes
# Out:
# year                        int64
# customer_id                 int64
# phone_no                   object
# gender                     object
# age                         int64
# no_of_days_subscribed       int64
# multi_screen               object
# mail_subscribed            object
# weekly_mins_watched       float64
# minimum_daily_mins        float64
# maximum_daily_mins        float64
# weekly_max_night_mins       int64
# videos_watched              int64
# maximum_days_inactive     float64
# customer_support_calls      int64
# churn                     float64
# dtype: object
