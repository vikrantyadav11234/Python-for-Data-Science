# %% [markdown]
# # Indexing and Slicing

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('datasets/citibike_tripdata.csv')
data
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32428 entries, 0 to 32427
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   tripduration         32428 non-null  int64
#  1   starttime            32428 non-null  object
#  2   stoptime             32428 non-null  object
#  3   start station id     32428 non-null  int64
#  4   start station name   32428 non-null  object
#  5   end station id       32428 non-null  int64
#  6   end station name     32428 non-null  object
#  7   bikeid               32428 non-null  int64
#  8   name_localizedValue  32428 non-null  object
#  9   usertype             32428 non-null  object
# dtypes: int64(4), object(6)
# memory usage: 2.5+ MB

# %%
data.describe()
# Out:
#         tripduration  start station id  end station id        bikeid
# count   32428.000000      32428.000000    32428.000000  32428.000000
# mean      798.978352       3264.568829     3255.485568  29817.647959
# std      9961.203954        137.810344      149.390306   2807.705863
# min        61.000000       3183.000000      212.000000  15271.000000
# 25%       236.000000       3192.000000     3186.000000  26310.000000
# 50%       352.000000       3206.000000     3203.000000  29516.000000
# 75%       590.000000       3272.000000     3270.000000  33568.000000
# max    936970.000000       3681.000000     3681.000000  33682.000000

# %%
data.head(10)
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 5           176  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
# 6           577  2018-05-01 05:05:46  2018-05-01 05:15:23              3225
# 7           830  2018-05-01 05:11:50  2018-05-01 05:25:41              3207
# 8           395  2018-05-01 05:12:07  2018-05-01 05:18:42              3225
# 9           170  2018-05-01 05:13:52  2018-05-01 05:16:43              3206
#
#       start station name  end station id end station name  bikeid  \
# ...

# %%
# Selecting a column
# one column
data['starttime']
# Out:
# 0        2018-05-01 00:04:47
# 1        2018-05-01 01:31:10
# 2        2018-05-01 01:31:29
# 3        2018-05-01 02:03:29
# 4        2018-05-01 04:27:12
#                 ...
# 32423    2018-05-30 13:49:18
# 32424    2018-05-30 13:49:21
# 32425    2018-05-30 13:49:51
# 32426    2018-05-30 13:50:52
# 32427    2018-05-30 13:50:58
# Name: starttime, Length: 32428, dtype: object

# %%
data[['starttime','stoptime']]
# Out:
#                  starttime             stoptime
# 0      2018-05-01 00:04:47  2018-05-01 00:10:25
# 1      2018-05-01 01:31:10  2018-05-01 01:55:53
# 2      2018-05-01 01:31:29  2018-05-01 01:35:22
# 3      2018-05-01 02:03:29  2018-05-01 02:06:40
# 4      2018-05-01 04:27:12  2018-05-01 04:32:16
# ...                    ...                  ...
# 32423  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427  2018-05-30 13:50:58  2018-05-30 13:57:08
#
# [32428 rows x 2 columns]

# %%
# Show top 20 data from bikeid

data['bikeid'].head(20)
# Out:
# 0     33558
# 1     33593
# 2     29217
# 3     29662
# 4     15271
# 5     29298
# 6     33619
# 7     33624
# 8     26300
# 9     33555
# 10    33627
# 11    26216
# 12    33592
# 13    26160
# 14    33640
# 15    26190
# 16    29530
# 17    26163
# 18    29571
# 19    33634
# Name: bikeid, dtype: int64

# %%
data
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               232  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
# Find a specific value

data['start station name'][2]
# Out:
# 'McGinley Square'

# %%
data['start station name'][2] = 'Paulus Hook'
# Out:
# C:\Users\MIT\AppData\Local\Temp\ipykernel_16648\1720967096.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['start station name'][2] = 'Paulus Hook'

# %%
data
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               300  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               400  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
data['tripduration'][2] = 300
# Out:
# C:\Users\MIT\AppData\Local\Temp\ipykernel_16648\633190871.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['tripduration'][2] = 300

# %%
data
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               300  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               190  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
data.at[4 , 'name_localizedValue']
# Out:
# '24 Hour'

# %%
# At

data.at[3 , 'tripduration'] = 400

# %% [markdown]
# # Slicing

# %% [markdown]
# # syntax1
#
# dataframe[ start : stop : step]
#
#
# # syntax2
# datafram['row_name_start' : 'row_name_end' : step]

# %%
data
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               300  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               400  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               400  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
data[0:5]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           300  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           400  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           400  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
#
#   start station name  end station id end station name  bikeid  \
# 0         Harborside            3199     Newport Pkwy   33558
# 1           Grand St            3185        City Hall   33593
# 2        Paulus Hook            3193     Lincoln Park   29217
# 3          City Hall            3186    Grove St PATH   29662
# 4        Oakland Ave            3195          Sip Ave   15271
#
#                        name_localizedValue    usertype
# 0                        Annual Membership  Subscriber
# ...

# %%
data[:10:2]
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 2           300  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 4           400  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 6           577  2018-05-01 05:05:46  2018-05-01 05:15:23              3225
# 8           395  2018-05-01 05:12:07  2018-05-01 05:18:42              3225
#
#       start station name  end station id end station name  bikeid  \
# 0             Harborside            3199     Newport Pkwy   33558
# 2            Paulus Hook            3193     Lincoln Park   29217
# 4            Oakland Ave            3195          Sip Ave   15271
# 6  Baldwin at Montgomery            3186    Grove St PATH   33619
# 8  Baldwin at Montgomery            3186    Grove St PATH   26300
#
#                        name_localizedValue    usertype
# 0                        Annual Membership  Subscriber
# ...

# %%
data[::-1]
# Out:
#        tripduration            starttime             stoptime  \
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# ...             ...                  ...                  ...
# 4               400  2018-05-01 04:27:12  2018-05-01 04:32:16
# 3               400  2018-05-01 02:03:29  2018-05-01 02:06:40
# 2               300  2018-05-01 01:31:29  2018-05-01 01:35:22
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
#
#        start station id   start station name  end station id end station name  \
# 32427              3220    5 Corners Library            3207      Oakland Ave
# ...

# %%
new_data = data[:11]
new_data
# Out:
#     tripduration            starttime             stoptime  start station id  \
# 0            338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1           1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2            300  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3            400  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4            400  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 5            176  2018-05-01 04:37:05  2018-05-01 04:40:01              3194
# 6            577  2018-05-01 05:05:46  2018-05-01 05:15:23              3225
# 7            830  2018-05-01 05:11:50  2018-05-01 05:25:41              3207
# 8            395  2018-05-01 05:12:07  2018-05-01 05:18:42              3225
# 9            170  2018-05-01 05:13:52  2018-05-01 05:16:43              3206
# 10           353  2018-05-01 05:18:36  2018-05-01 05:24:29              3225
#
# ...

# %%
new_data = data.head(5)
new_data
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           300  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           400  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           400  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
#
#   start station name  end station id end station name  bikeid  \
# 0         Harborside            3199     Newport Pkwy   33558
# 1           Grand St            3185        City Hall   33593
# 2        Paulus Hook            3193     Lincoln Park   29217
# 3          City Hall            3186    Grove St PATH   29662
# 4        Oakland Ave            3195          Sip Ave   15271
#
#                        name_localizedValue    usertype
# 0                        Annual Membership  Subscriber
# ...

# %%
idx = ['row_1','row_2','row_3','row_4','row_5']

# %%
new_data.index = idx

# %%
new_data
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           300  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           400  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_5           400  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_2              3681           Grand St            3185        City Hall
# row_3              3194        Paulus Hook            3193     Lincoln Park
# row_4              3185          City Hall            3186    Grove St PATH
# row_5              3207        Oakland Ave            3195          Sip Ave
#
#        bikeid                      name_localizedValue    usertype
# row_1   33558                        Annual Membership  Subscriber
# ...

# %%
new_data[0:3]
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           300  2018-05-01 01:31:29  2018-05-01 01:35:22
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_2              3681           Grand St            3185        City Hall
# row_3              3194        Paulus Hook            3193     Lincoln Park
#
#        bikeid                      name_localizedValue    usertype
# row_1   33558                        Annual Membership  Subscriber
# row_2   33593                                  24 Hour    Customer
# row_3   29217  FREE Bonus Month with Annual Membership  Subscriber

# %%
new_data['row_1' :'row_4']
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           300  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           400  2018-05-01 02:03:29  2018-05-01 02:06:40
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_2              3681           Grand St            3185        City Hall
# row_3              3194        Paulus Hook            3193     Lincoln Park
# row_4              3185          City Hall            3186    Grove St PATH
#
#        bikeid                      name_localizedValue    usertype
# row_1   33558                        Annual Membership  Subscriber
# row_2   33593                                  24 Hour    Customer
# row_3   29217  FREE Bonus Month with Annual Membership  Subscriber
# ...

# %%
new_data
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           300  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           400  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_5           400  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_2              3681           Grand St            3185        City Hall
# row_3              3194        Paulus Hook            3193     Lincoln Park
# row_4              3185          City Hall            3186    Grove St PATH
# row_5              3207        Oakland Ave            3195          Sip Ave
#
#        bikeid                      name_localizedValue    usertype
# row_1   33558                        Annual Membership  Subscriber
# ...

# %%
# LOC method

- dows the slicing on both the rows as well as columns


syntax -
datafram.loc[row_name_start : row_name_stop: step , column start : column stop: step]

- Zero indexing is not possible
- you can pass condition

# %%
data.loc[0:10:2]
# Out:
#     tripduration            starttime             stoptime  start station id  \
# 0            338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 2            300  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 4            400  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# 6            577  2018-05-01 05:05:46  2018-05-01 05:15:23              3225
# 8            395  2018-05-01 05:12:07  2018-05-01 05:18:42              3225
# 10           353  2018-05-01 05:18:36  2018-05-01 05:24:29              3225
#
#        start station name  end station id end station name  bikeid  \
# 0              Harborside            3199     Newport Pkwy   33558
# 2             Paulus Hook            3193     Lincoln Park   29217
# 4             Oakland Ave            3195          Sip Ave   15271
# 6   Baldwin at Montgomery            3186    Grove St PATH   33619
# 8   Baldwin at Montgomery            3186    Grove St PATH   26300
# ...

# %%
new_data
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           300  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           400  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_5           400  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_2              3681           Grand St            3185        City Hall
# row_3              3194        Paulus Hook            3193     Lincoln Park
# row_4              3185          City Hall            3186    Grove St PATH
# row_5              3207        Oakland Ave            3195          Sip Ave
#
#        bikeid                      name_localizedValue    usertype
# row_1   33558                        Annual Membership  Subscriber
# ...

# %%
new_data.loc['row_2': 'row_4']
# Out:
#        tripduration            starttime             stoptime  \
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           300  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           400  2018-05-01 02:03:29  2018-05-01 02:06:40
#
#        start station id start station name  end station id end station name  \
# row_2              3681           Grand St            3185        City Hall
# row_3              3194        Paulus Hook            3193     Lincoln Park
# row_4              3185          City Hall            3186    Grove St PATH
#
#        bikeid                      name_localizedValue    usertype
# row_2   33593                                  24 Hour    Customer
# row_3   29217  FREE Bonus Month with Annual Membership  Subscriber
# row_4   29662                                  24 Hour    Customer

# %%
new_data.loc[['row_2', 'row_4' , 'row_5']]
# Out:
#        tripduration            starttime             stoptime  \
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_4           400  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_5           400  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#        start station id start station name  end station id end station name  \
# row_2              3681           Grand St            3185        City Hall
# row_4              3185          City Hall            3186    Grove St PATH
# row_5              3207        Oakland Ave            3195          Sip Ave
#
#        bikeid name_localizedValue    usertype
# row_2   33593             24 Hour    Customer
# row_4   29662             24 Hour    Customer
# row_5   15271   Annual Membership  Subscriber

# %%
new_data.loc[['row_2', 'row_3' , 'row_5'] , ['tripduration' , 'bikeid','usertype']]
# Out:
#        tripduration  bikeid    usertype
# row_2          1482   33593    Customer
# row_3           300   29217  Subscriber
# row_5           400   15271  Subscriber

# %%
new_data.loc['row_1':'row_4' , ['tripduration','starttime' , 'bikeid']]
# Out:
#        tripduration            starttime  bikeid
# row_1           338  2018-05-01 00:04:47   33558
# row_2          1482  2018-05-01 01:31:10   33593
# row_3           300  2018-05-01 01:31:29   29217
# row_4           400  2018-05-01 02:03:29   29662

# %%
new_data
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           300  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           400  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_5           400  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_2              3681           Grand St            3185        City Hall
# row_3              3194        Paulus Hook            3193     Lincoln Park
# row_4              3185          City Hall            3186    Grove St PATH
# row_5              3207        Oakland Ave            3195          Sip Ave
#
#        bikeid                      name_localizedValue    usertype
# row_1   33558                        Annual Membership  Subscriber
# ...

# %%
# Filter of the data

# get only those data where tripduration > 350

# %%
new_data.loc[new_data['tripduration']> 350 , ['tripduration' , 'usertype']]
# Out:
#        tripduration    usertype
# row_2          1482    Customer
# row_4           400    Customer
# row_5           400  Subscriber

# %%
new_data.loc[new_data['tripduration']> 350 , 'tripduration' : 'usertype':2]
# Out:
#        tripduration             stoptime start station name end station name  \
# row_2          1482  2018-05-01 01:55:53           Grand St        City Hall
# row_4           400  2018-05-01 02:06:40          City Hall    Grove St PATH
# row_5           400  2018-05-01 04:32:16        Oakland Ave          Sip Ave
#
#       name_localizedValue
# row_2             24 Hour
# row_4             24 Hour
# row_5   Annual Membership

# %%
new_data.loc['row_1'::2 , ::2]
# Out:
#        tripduration             stoptime start station name end station name  \
# row_1           338  2018-05-01 00:10:25         Harborside     Newport Pkwy
# row_3           300  2018-05-01 01:35:22        Paulus Hook     Lincoln Park
# row_5           400  2018-05-01 04:32:16        Oakland Ave          Sip Ave
#
#                            name_localizedValue
# row_1                        Annual Membership
# row_3  FREE Bonus Month with Annual Membership
# row_5                        Annual Membership

# %%
new_data.loc[:: , 'tripduration':'name_localizedValue']
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           300  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           400  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_5           400  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_2              3681           Grand St            3185        City Hall
# row_3              3194        Paulus Hook            3193     Lincoln Park
# row_4              3185          City Hall            3186    Grove St PATH
# row_5              3207        Oakland Ave            3195          Sip Ave
#
#        bikeid                      name_localizedValue
# row_1   33558                        Annual Membership
# ...

# %%
new_data
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           300  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           400  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_5           400  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_2              3681           Grand St            3185        City Hall
# row_3              3194        Paulus Hook            3193     Lincoln Park
# row_4              3185          City Hall            3186    Grove St PATH
# row_5              3207        Oakland Ave            3195          Sip Ave
#
#        bikeid                      name_localizedValue    usertype
# row_1   33558                        Annual Membership  Subscriber
# ...

# %%
# where tripduration > 350 and usertype = Subscriber

# %%
data
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               300  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               400  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               400  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
data.loc[(data['tripduration']>350) & (data['usertype'] == 'Subscriber')]
# Out:
#        tripduration            starttime             stoptime  \
# 4               400  2018-05-01 04:27:12  2018-05-01 04:32:16
# 6               577  2018-05-01 05:05:46  2018-05-01 05:15:23
# 7               830  2018-05-01 05:11:50  2018-05-01 05:25:41
# 8               395  2018-05-01 05:12:07  2018-05-01 05:18:42
# 10              353  2018-05-01 05:18:36  2018-05-01 05:24:29
# ...             ...                  ...                  ...
# 32417           622  2018-05-30 13:40:03  2018-05-30 13:50:26
# 32420           485  2018-05-30 13:44:46  2018-05-30 13:52:51
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id     start station name  end station id  \
# 4                  3207            Oakland Ave            3195
# 6                  3225  Baldwin at Montgomery            3186
# ...

# %% [markdown]
# # iloc

# %% [markdown]
# - we can do slicing based on rows as well as columns
# - Zero indexing is possible
#
#
# syntax-
# dataframe.iloc[row_index_start : row_index_stop : step , column_index_start : column_index_stop : step]

# %%
new_data
# Out:
#        tripduration            starttime             stoptime  \
# row_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# row_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# row_3           300  2018-05-01 01:31:29  2018-05-01 01:35:22
# row_4           400  2018-05-01 02:03:29  2018-05-01 02:06:40
# row_5           400  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#        start station id start station name  end station id end station name  \
# row_1              3639         Harborside            3199     Newport Pkwy
# row_2              3681           Grand St            3185        City Hall
# row_3              3194        Paulus Hook            3193     Lincoln Park
# row_4              3185          City Hall            3186    Grove St PATH
# row_5              3207        Oakland Ave            3195          Sip Ave
#
#        bikeid                      name_localizedValue    usertype
# row_1   33558                        Annual Membership  Subscriber
# ...

# %%
new_data.loc[0:3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [110], in <cell line: 1>()
# ----> 1 new_data.loc[0:3]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1180, in _LocIndexer._getitem_axis(self, key, axis)
#    1178 if isinstance(key, slice):
#    1179     self._validate_key(key, axis)
# -> 1180     return self._get_slice_axis(key, axis=axis)
#    1181 elif com.is_bool_indexer(key):
#    1182     return self._getbool_axis(key, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1214, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
# ...

# %% [markdown]
# # normal slicing
# - column slicing is not possible
# - row slicing is possible
# - zero indexing is possible
#
# # loc
# - both row and column slicing is possible
# - drawback - it is limited only to the row and column name
# - zero indexing is not possible
#
# # iloc
# - both row and column slicing is possible
# - zero indexing is possible
# - custom names are not allowed for slicing

# %%
data['name_localizedValue'].unique()
# Out:
# array(['Annual Membership', '24 Hour',
#        'FREE Bonus Month with Annual Membership',
#        'Annual Membership from Citi Bike App',
#        '$25 Off Annual Membership', 'Join Citi Bike for $14.95/month',
#        'Single Ride', 'JCBS Employee', 'Citi Bike Annual Membership',
#        'Annual Membership - Save 15%', '3 Day', 'Day Pass',
#        'NYCHA Membership (Renewal)', 'Join Citi Bike for $14/month',
#        'Citi Bike for Business Annual Membership',
#        '$35 Off Annual Membership', 'JCHA Annual Membership $5/month',
#        'CDCU', 'NYCHA Membership', '3-Day Pass from Citi Bike App',
#        'Single Ride POS',
#        'Annual Membership - Save $25 to Celebrate Expansion',
#        'Annual Membership - 10% Off', 'CDCU (renewal)',
#        '$99 Annual Membership', 'Motivate Employee', 'NYCBS Employee',
#        'NYCHA POS',
#        'Bike Angels Reward Memberships - Annual member with removed 2 minute delay',
# ...

# %%
tripduration > 400 and usertype == Subscriber and name_localizedValue == Annual Membership
# Out:
#        tripduration            starttime             stoptime  \
# 0               338  2018-05-01 00:04:47  2018-05-01 00:10:25
# 1              1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# 2               300  2018-05-01 01:31:29  2018-05-01 01:35:22
# 3               400  2018-05-01 02:03:29  2018-05-01 02:06:40
# 4               400  2018-05-01 04:27:12  2018-05-01 04:32:16
# ...             ...                  ...                  ...
# 32423           396  2018-05-30 13:49:18  2018-05-30 13:55:55
# 32424           313  2018-05-30 13:49:21  2018-05-30 13:54:35
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 0                  3639           Harborside            3199     Newport Pkwy
# ...

# %%
data.loc[(data['tripduration']>400) & (data['usertype']=='Subscriber') & 
         (data['name_localizedValue']=='Annual Membership')]
# Out:
#        tripduration            starttime             stoptime  \
# 7               830  2018-05-01 05:11:50  2018-05-01 05:25:41
# 11              704  2018-05-01 05:23:26  2018-05-01 05:35:11
# 14              473  2018-05-01 05:34:23  2018-05-01 05:42:16
# 22              418  2018-05-01 06:04:09  2018-05-01 06:11:07
# 26              617  2018-05-01 06:07:04  2018-05-01 06:17:21
# ...             ...                  ...                  ...
# 32404           419  2018-05-30 13:20:50  2018-05-30 13:27:50
# 32411           873  2018-05-30 13:29:58  2018-05-30 13:44:32
# 32414           402  2018-05-30 13:35:49  2018-05-30 13:42:32
# 32417           622  2018-05-30 13:40:03  2018-05-30 13:50:26
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
#
#        start station id     start station name  end station id  \
# 7                  3207            Oakland Ave            3185
# 11                 3185              City Hall            3187
# ...

# %% [markdown]
# # Adding a new column in the dataframe

# %%
df = pd.read_csv('datasets/international_org.csv')
df
# Out:
#   Organization Name  Headquater
# 0               FAO        Rome
# 1               ICJ   The Hague
# 2               IMF  Washington
# 3            UNESCO       Paris
# 4               UNO    New York
# 5        World Bank  Washington

# %%
# Adding a new column in the dataframe
df['Estashment year'] = 1945

# %%
df
# Out:
#   Organization Name  Headquater  Estashment year
# 0               FAO        Rome             1945
# 1               ICJ   The Hague             1945
# 2               IMF  Washington             1945
# 3            UNESCO       Paris             1945
# 4               UNO    New York             1945
# 5        World Bank  Washington             1945

# %%
# Adding a new column in the dataframe
df['Estashment year'] = [1, 2, 3,4,5,6]

# %%
df
# Out:
#   Organization Name  Headquater  Estashment year
# 0               FAO        Rome                1
# 1               ICJ   The Hague                2
# 2               IMF  Washington                3
# 3            UNESCO       Paris                4
# 4               UNO    New York                5
# 5        World Bank  Washington                6

# %%
# Adding a new column in the dataframe
df['Estashment year'] = pd.Series([1, 2, 3,4,5])

# %%
df
# Out:
#   Organization Name  Headquater  Estashment year
# 0               FAO        Rome              1.0
# 1               ICJ   The Hague              2.0
# 2               IMF  Washington              3.0
# 3            UNESCO       Paris              4.0
# 4               UNO    New York              5.0
# 5        World Bank  Washington              NaN

# %%
# Adding a mutiple columns in the dataframe
df[['Estashment year' , 'Year']] = pd.Series([[1,2,3,4,5,6],[1,2,3,4,5,6]])

# %%
df
# Out:
#   Organization Name  Headquater  Estashment year  Year
# 0               FAO        Rome                1     1
# 1               ICJ   The Hague                2     2
# 2               IMF  Washington                3     3
# 3            UNESCO       Paris                4     4
# 4               UNO    New York                5     5
# 5        World Bank  Washington                6     6

# %%
# Deleting
del df['Year']

# %%
df
# Out:
#   Organization Name  Headquater  Estashment year
# 0               FAO        Rome                1
# 1               ICJ   The Hague                2
# 2               IMF  Washington                3
# 3            UNESCO       Paris                4
# 4               UNO    New York                5
# 5        World Bank  Washington                6

# %% [markdown]
# # Rows

# %%
rating = pd.read_csv('datasets/imdb_rating.csv')
rating
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
rating['genre'][3]
# Out:
# 'Action'

# %%
rating.at[3 , 'genre']
# Out:
# 'Action'

# %%
'Crime' ----> 'crime'

# %%
for i in rating.index:
    if rating.loc[i,'genre'] == 'Crime':
        rating.loc[i,'genre'] = 'crime'

# %%
for i in rating.index:
    if rating.at[i , 'genre'] == 'Crime':
        rating.at[i ,'genre'] = 'crime'

# %%
rating
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      crime
# 1          9.2                                  The Godfather      crime
# 2          9.1                         The Godfather: Part II      crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %% [markdown]
# # Row wise

# %%
rating
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      crime
# 1          9.2                                  The Godfather      crime
# 2          9.1                         The Godfather: Part II      crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
rating.loc[0] = [8.9 , 'Money Hiest' , 'action' , 60]

# %%
rating
# Out:
#    star_rating                                          title      genre  \
# 0          8.9                                    Money Hiest     action
# 1          9.2                                  The Godfather      Crime
# 2          9.1                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.9                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.9                               Schindler's List  Biography
# 9          8.9                                     Fight Club      Drama
#
#    duration
# 0        60
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
rating.loc[10] = [8.9 , 'Money Hiest' , 'action' , 60]

# %%
rating
# Out:
#     star_rating                                          title      genre  \
# 0           8.9                                    Money Hiest     action
# 1           9.2                                  The Godfather      Crime
# 2           9.1                         The Godfather: Part II      Crime
# 3           9.0                                The Dark Knight     Action
# 4           8.9                                   Pulp Fiction      Crime
# 5           8.9                                   12 Angry Men      Drama
# 6           8.9                 The Good, the Bad and the Ugly    Western
# 7           8.9  The Lord of the Rings: The Return of the King  Adventure
# 8           8.9                               Schindler's List  Biography
# 9           8.9                                     Fight Club      Drama
# 10          8.9                                    Money Hiest     action
#
#     duration
# 0         60
# 1        175
# 2        200
# 3        152
# ...

# %%
rating.index[-1]+1
# Out:
# 11

# %%
rating.loc[rating.index[-1]+1] = [8.9 , 'Money Hiest' , 'action' , 60]

# %%
rating
# Out:
#     star_rating                                          title      genre  \
# 0           8.9                                    Money Hiest     action
# 1           9.2                                  The Godfather      Crime
# 2           9.1                         The Godfather: Part II      Crime
# 3           9.0                                The Dark Knight     Action
# 4           8.9                                   Pulp Fiction      Crime
# 5           8.9                                   12 Angry Men      Drama
# 6           8.9                 The Good, the Bad and the Ugly    Western
# 7           8.9  The Lord of the Rings: The Return of the King  Adventure
# 8           8.9                               Schindler's List  Biography
# 9           8.9                                     Fight Club      Drama
# 10          8.9                                    Money Hiest     action
# 11          8.9                                    Money Hiest     action
# ...

# %% [markdown]
# # Drop

# %%
rating
# Out:
#     star_rating                                          title      genre  \
# 0           8.9                                    Money Hiest     action
# 1           9.2                                  The Godfather      Crime
# 2           9.1                         The Godfather: Part II      Crime
# 3           9.0                                The Dark Knight     Action
# 4           8.9                                   Pulp Fiction      Crime
# 5           8.9                                   12 Angry Men      Drama
# 6           8.9                 The Good, the Bad and the Ugly    Western
# 7           8.9  The Lord of the Rings: The Return of the King  Adventure
# 8           8.9                               Schindler's List  Biography
# 9           8.9                                     Fight Club      Drama
# 10          8.9                                    Money Hiest     action
# 11          8.9                                    Money Hiest     action
# ...

# %%
rating.drop(index = 14 , inplace = True)

# %%
rating
# Out:
#     star_rating                                          title      genre  \
# 0           8.9                                    Money Hiest     action
# 1           9.2                                  The Godfather      Crime
# 2           9.1                         The Godfather: Part II      Crime
# 3           9.0                                The Dark Knight     Action
# 4           8.9                                   Pulp Fiction      Crime
# 5           8.9                                   12 Angry Men      Drama
# 6           8.9                 The Good, the Bad and the Ugly    Western
# 7           8.9  The Lord of the Rings: The Return of the King  Adventure
# 8           8.9                               Schindler's List  Biography
# 9           8.9                                     Fight Club      Drama
# 10          8.9                                    Money Hiest     action
# 11          8.9                                    Money Hiest     action
# ...

# %%
rating.drop(index = [12,11] , inplace = True)

# %%
rating
# Out:
#     star_rating                                          title      genre  \
# 0           8.9                                    Money Hiest     action
# 1           9.2                                  The Godfather      Crime
# 2           9.1                         The Godfather: Part II      Crime
# 3           9.0                                The Dark Knight     Action
# 4           8.9                                   Pulp Fiction      Crime
# 5           8.9                                   12 Angry Men      Drama
# 6           8.9                 The Good, the Bad and the Ugly    Western
# 7           8.9  The Lord of the Rings: The Return of the King  Adventure
# 8           8.9                               Schindler's List  Biography
# 9           8.9                                     Fight Club      Drama
# 10          8.9                                    Money Hiest     action
#
#     duration
# 0         60
# 1        175
# 2        200
# 3        152
# ...

# %% [markdown]
# # Iterating over a Dataframe

# %% [markdown]
# 1. itertuple
# 2. iterrows
# 3. iteritems

# %%
space_org = {'Organizations_name' : ["CNES", "ISRO", "NASA", "JAXA", "CNSA"],
                   'Headquarters' : ["Paris", "Bangalore", "Washington",
                                     "Tokyo", "Beijing"],
                   'Country_name' : ["France", "India", "USA", "Japan", "China"],
                 'Formation_year' : [1961, 1969, 1958, 2003, 1993]
             }

# %%
df = pd.DataFrame(space_org)
df
# Out:
#   Organizations_name Headquarters Country_name  Formation_year
# 0               CNES        Paris       France            1961
# 1               ISRO    Bangalore        India            1969
# 2               NASA   Washington          USA            1958
# 3               JAXA        Tokyo        Japan            2003
# 4               CNSA      Beijing        China            1993

# %% [markdown]
# # 1. itertuples

# %%
for i in df.itertuples():
    print(i)
# Out:
# Pandas(Index=0, Organizations_name='CNES', Headquarters='Paris', Country_name='France', Formation_year=1961)
# Pandas(Index=1, Organizations_name='ISRO', Headquarters='Bangalore', Country_name='India', Formation_year=1969)
# Pandas(Index=2, Organizations_name='NASA', Headquarters='Washington', Country_name='USA', Formation_year=1958)
# Pandas(Index=3, Organizations_name='JAXA', Headquarters='Tokyo', Country_name='Japan', Formation_year=2003)
# Pandas(Index=4, Organizations_name='CNSA', Headquarters='Beijing', Country_name='China', Formation_year=1993)

# %%
df
# Out:
#   Organizations_name Headquarters Country_name  Formation_year
# 0               CNES        Paris       France            1961
# 1               ISRO    Bangalore        India            1969
# 2               NASA   Washington          USA            1958
# 3               JAXA        Tokyo        Japan            2003
# 4               CNSA      Beijing        China            1993

# %%
for i in df.itertuples():
    if i.Organizations_name == 'CNES':
        print(i.Headquarters)
# Out:
# Paris

# %% [markdown]
# # 2. iterrows

# %%
df
# Out:
#   Organizations_name Headquarters Country_name  Formation_year
# 0               CNES        Paris       France            1961
# 1               ISRO    Bangalore        India            1969
# 2               NASA   Washington          USA            1958
# 3               JAXA        Tokyo        Japan            2003
# 4               CNSA      Beijing        China            1993

# %%
for i in df.iterrows():
    print(i)
# Out:
# (0, Organizations_name      CNES
# Headquarters           Paris
# Country_name          France
# Formation_year          1961
# Name: 0, dtype: object)
# (1, Organizations_name         ISRO
# Headquarters          Bangalore
# Country_name              India
# Formation_year             1969
# Name: 1, dtype: object)
# (2, Organizations_name          NASA
# Headquarters          Washington
# Country_name                 USA
# Formation_year              1958
# Name: 2, dtype: object)
# (3, Organizations_name     JAXA
# Headquarters          Tokyo
# Country_name          Japan
# Formation_year         2003
# Name: 3, dtype: object)
# (4, Organizations_name       CNSA
# Headquarters          Beijing
# Country_name            China
# Formation_year           1993
# Name: 4, dtype: object)

# %%
(0 , Organizations_name       CNSA
Headquarters          Beijing
Country_name            China
Formation_year           1993
Name: 4, dtype: object)

# %%
tup = [(0 , 'python') , (1, 'learnbay')]

for i in tup:
    print(i[1])
# Out:
# python
# learnbay

# %%
for i in df.iterrows():
    print(i[1], end = '\n\n\n')
# Out:
# Organizations_name      CNES
# Headquarters           Paris
# Country_name          France
# Formation_year          1961
# Name: 0, dtype: object
#
#
# Organizations_name         ISRO
# Headquarters          Bangalore
# Country_name              India
# Formation_year             1969
# Name: 1, dtype: object
#
#
# Organizations_name          NASA
# Headquarters          Washington
# Country_name                 USA
# Formation_year              1958
# Name: 2, dtype: object
#
#
# Organizations_name     JAXA
# Headquarters          Tokyo
# Country_name          Japan
# Formation_year         2003
# Name: 3, dtype: object
#
#
# Organizations_name       CNSA
# Headquarters          Beijing
# Country_name            China
# Formation_year           1993
# Name: 4, dtype: object

# %%
for i in df.iterrows():
    print(i[1]['Organizations_name'])
# Out:
# CNES
# ISRO
# NASA
# JAXA
# CNSA

# %%
for i in df.iterrows():
    if i[1]['Organizations_name'] == 'ISRO':
        print(i[1]['Headquarters'])
# Out:
# Bangalore

# %%
for i in df.itertuples():
    if i.Organizations_name == 'ISRO':
        print(i.Headquarters)
# Out:
# Bangalore

# %% [markdown]
# # Iteritems

# %%
df
# Out:
#   Organizations_name Headquarters Country_name  Formation_year
# 0               CNES        Paris       France            1961
# 1               ISRO    Bangalore        India            1969
# 2               NASA   Washington          USA            1958
# 3               JAXA        Tokyo        Japan            2003
# 4               CNSA      Beijing        China            1993

# %%
for i in df.iteritems():
    print(i[1], end = '\n\n\n')
# Out:
# 0    CNES
# 1    ISRO
# 2    NASA
# 3    JAXA
# 4    CNSA
# Name: Organizations_name, dtype: object
#
#
# 0         Paris
# 1     Bangalore
# 2    Washington
# 3         Tokyo
# 4       Beijing
# Name: Headquarters, dtype: object
#
#
# 0    France
# 1     India
# 2       USA
# 3     Japan
# 4     China
# Name: Country_name, dtype: object
#
#
# 0    1961
# 1    1969
# 2    1958
# 3    2003
# 4    1993
# Name: Formation_year, dtype: int64

# %% [markdown]
# ### NEXT WEEK

# %% [markdown]
# # Sorting of the dataframe

# %%
df = pd.read_csv('datasets/unsorted_imdb_rating.csv')
df
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 1          9.1                                  The Godfather      Crime
# 2          9.2                         The Godfather: Part II      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.8                                   12 Angry Men      Drama
# 6          8.7                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 8          8.3                               Schindler's List  Biography
# 9          8.1                                     Fight Club      Drama
#
#    duration
# 0       142
# 1       175
# 2       200
# 3       152
# 4       154
# 5        96
# 6       161
# 7       201
# 8       195
# 9       139

# %%
df.sort_values(by = 'duration' , inplace = True)

# %%
df
# Out:
#    star_rating                                          title      genre  \
# 5          8.8                                   12 Angry Men      Drama
# 9          8.1                                     Fight Club      Drama
# 0          9.3                       The Shawshank Redemption      Crime
# 3          9.0                                The Dark Knight     Action
# 4          8.9                                   Pulp Fiction      Crime
# 6          8.7                 The Good, the Bad and the Ugly    Western
# 1          9.1                                  The Godfather      Crime
# 8          8.3                               Schindler's List  Biography
# 2          9.2                         The Godfather: Part II      Crime
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
#
#    duration
# 5        96
# 9       139
# 0       142
# 3       152
# 4       154
# 6       161
# 1       175
# 8       195
# 2       200
# 7       201

# %%
df.sort_values(by = ['star_rating' , 'duration'] , inplace = True,ascending=False)

# %%
df
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 2          9.2                         The Godfather: Part II      Crime
# 1          9.1                                  The Godfather      Crime
# 3          9.0                                The Dark Knight     Action
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.8                                   12 Angry Men      Drama
# 6          8.7                 The Good, the Bad and the Ugly    Western
# 8          8.3                               Schindler's List  Biography
# 9          8.1                                     Fight Club      Drama
#
#    duration
# 0       142
# 2       200
# 1       175
# 3       152
# 7       201
# 4       154
# 5        96
# 6       161
# 8       195
# 9       139

# %%
df.at[5 , 'star_rating'] = 8.9

# %%
df
# Out:
#    star_rating                                          title      genre  \
# 0          9.3                       The Shawshank Redemption      Crime
# 2          9.2                         The Godfather: Part II      Crime
# 1          9.1                                  The Godfather      Crime
# 3          9.0                                The Dark Knight     Action
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          8.7                 The Good, the Bad and the Ugly    Western
# 8          8.3                               Schindler's List  Biography
# 9          8.1                                     Fight Club      Drama
#
#    duration
# 0       142
# 2       200
# 1       175
# 3       152
# 7       201
# 4       154
# 5        96
# 6       161
# 8       195
# 9       139

# %%
df.sort_values(by = ['star_rating' , 'duration'] , inplace = True , ascending= [True , False])

# %%
df
# Out:
#    star_rating                                          title      genre  \
# 9          8.1                                     Fight Club      Drama
# 8          8.3                               Schindler's List  Biography
# 6          8.7                 The Good, the Bad and the Ugly    Western
# 7          8.9  The Lord of the Rings: The Return of the King  Adventure
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 3          9.0                                The Dark Knight     Action
# 1          9.1                                  The Godfather      Crime
# 2          9.2                         The Godfather: Part II      Crime
# 0          9.3                       The Shawshank Redemption      Crime
#
#    duration
# 9       139
# 8       195
# 6       161
# 7       201
# 4       154
# 5        96
# 3       152
# 1       175
# 2       200
# 0       142

# %%
df.sort_values(by = ['star_rating' , 'duration'] , inplace = True , 
               ascending= [True , False], ignore_index= True)

# %%
df
# Out:
#    star_rating                                          title      genre  \
# 0          8.1                                     Fight Club      Drama
# 1          8.3                               Schindler's List  Biography
# 2          8.7                 The Good, the Bad and the Ugly    Western
# 3          8.9  The Lord of the Rings: The Return of the King  Adventure
# 4          8.9                                   Pulp Fiction      Crime
# 5          8.9                                   12 Angry Men      Drama
# 6          9.0                                The Dark Knight     Action
# 7          9.1                                  The Godfather      Crime
# 8          9.2                         The Godfather: Part II      Crime
# 9          9.3                       The Shawshank Redemption      Crime
#
#    duration
# 0       139
# 1       195
# 2       161
# 3       201
# 4       154
# 5        96
# 6       152
# 7       175
# 8       200
# 9       142

# %% [markdown]
# # Concatination

# %%
india_weather = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
    "humidity": [80, 60, 78]
})
india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
us_weather = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
    "humidity": [68, 65, 75]
})
us_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
com_df = pd.concat([india_weather , us_weather])
com_df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
# 1 st way

com_df = pd.concat([india_weather , us_weather] , ignore_index= True)
com_df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york           21        68
# 4   chicago           14        65
# 5   orlando           35        75

# %%
# 2nd way

com_df.reset_index(drop = True , inplace = True)
com_df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york           21        68
# 4   chicago           14        65
# 5   orlando           35        75

# %%
india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
us_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df = pd.concat([india_weather , us_weather] , keys = ['INDIA' , 'US'] )
df
# Out:
#              city  temperature  humidity
# INDIA 0    mumbai           32        80
#       1     delhi           45        60
#       2  banglore           30        78
# US    0  new york           21        68
#       1   chicago           14        65
#       2   orlando           35        75

# %%
df.loc['INDIA']
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
df.rename(columns= {'temperature' : 'temp'})
# Out:
#              city  temp  humidity
# INDIA 0    mumbai    32        80
#       1     delhi    45        60
#       2  banglore    30        78
# US    0  new york    21        68
#       1   chicago    14        65
#       2   orlando    35        75

# %%
com_df
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78
# 3  new york           21        68
# 4   chicago           14        65
# 5   orlando           35        75

# %%
com_df.set_index('city' , inplace = True)

com_df
# Out:
#           temperature  humidity
# city
# mumbai             32        80
# delhi              45        60
# banglore           30        78
# new york           21        68
# chicago            14        65
# orlando            35        75

# %%
com_df.at['banglore' , 'temperature']
# Out:
# 30

# %%
com_df['humidity']['delhi']
# Out:
# 60

# %% [markdown]
# # Merge

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
})
df1
# Out:
#        city  temperature
# 0  new york           21
# 1   chicago           14
# 2   orlando           35

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","orlando"],
    "humidity": [65,68,75],
})
df2
# Out:
#        city  humidity
# 0   chicago        65
# 1  new york        68
# 2   orlando        75

# %%
df = pd.concat([df1 , df2])
df
# Out:
#        city  temperature  humidity
# 0  new york         21.0       NaN
# 1   chicago         14.0       NaN
# 2   orlando         35.0       NaN
# 0   chicago          NaN      65.0
# 1  new york          NaN      68.0
# 2   orlando          NaN      75.0

# %%
df = pd.merge(df1 , df2 , how = 'inner')
df
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35, 38],
})
df1
# Out:
#         city  temperature
# 0   new york           21
# 1    chicago           14
# 2    orlando           35
# 3  baltimore           38

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","san diego"],
    "humidity": [65,68,71],
})
df2
# Out:
#         city  humidity
# 0    chicago        65
# 1   new york        68
# 2  san diego        71

# %%
# inner join
df = pd.merge(df1 , df2 , how = 'inner')
df
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65

# %%
# outer join
df = pd.merge(df1 , df2 , how = 'outer')
df
# Out:
#         city  temperature  humidity
# 0   new york         21.0      68.0
# 1    chicago         14.0      65.0
# 2    orlando         35.0       NaN
# 3  baltimore         38.0       NaN
# 4  san diego          NaN      71.0

# %%
# left join
df = pd.merge(df1 , df2 , how = 'left')
df
# Out:
#         city  temperature  humidity
# 0   new york           21      68.0
# 1    chicago           14      65.0
# 2    orlando           35       NaN
# 3  baltimore           38       NaN

# %%
df1
# Out:
#         city  temperature
# 0   new york           21
# 1    chicago           14
# 2    orlando           35
# 3  baltimore           38

# %%
df2
# Out:
#         city  humidity
# 0    chicago        65
# 1   new york        68
# 2  san diego        71

# %%
# right join
df = pd.merge(df1 , df2 , how = 'right')
df
# Out:
#         city  temperature  humidity
# 0    chicago         14.0        65
# 1   new york         21.0        68
# 2  san diego          NaN        71

# %%
# outer join
df = pd.merge(df1 , df2 , how = 'outer' , indicator= True)
df
# Out:
#         city  temperature  humidity      _merge
# 0   new york         21.0      68.0        both
# 1    chicago         14.0      65.0        both
# 2    orlando         35.0       NaN   left_only
# 3  baltimore         38.0       NaN   left_only
# 4  san diego          NaN      71.0  right_only

# %% [markdown]
# # Handling missing data
